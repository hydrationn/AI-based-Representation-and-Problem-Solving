# %% [markdown]
# <a href="https://colab.research.google.com/github/hydrationn/AI-based-Representation-and-Problem-Solving/blob/main/202101109_%EB%B0%95%EC%88%98%ED%99%94_%EA%B3%BC%EC%A0%9C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

batch_size = 4

# CIFAR-10 데이터셋을 위한 변환(transformation) 정의
transform = transforms.Compose(
    [transforms.ToTensor()])

# CIFAR-10 훈련 데이터셋 로드
trainset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4,
                                          shuffle=True, num_workers=2)

# CIFAR-10 클래스 정의
classes = ('Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
               'Dog', 'Frog', 'Horse', 'Ship', 'Truck')

# 이미지 시각화 함수
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# 이미지와 레이블을 불러온다
dataiter = iter(trainloader)
images, labels = next(dataiter)

# 이미지를 그리드 형태로 만들어 시각화한다
imshow(torchvision.utils.make_grid(images))

# 레이블 출력과 이미지의 형태 출력
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(4)))
print(images[0].numpy().shape)
# Out:
# Files already downloaded and verified
# Truck Horse Frog  Deer
# (3, 32, 32)
